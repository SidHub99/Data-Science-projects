# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Heart_Disease_Prediction.csv")

# %%
df.head()
# Out:
#    index  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0      0   70    1                4  130          322             0
# 1      1   67    0                3  115          564             0
# 2      2   57    1                2  124          261             0
# 3      3   64    1                4  128          263             0
# 4      4   74    0                2  120          269             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     109                0            2.4            2
# 1            2     160                0            1.6            2
# 2            0     141                0            0.3            1
# 3            0     105                1            0.2            2
# 4            2     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    270 non-null    int64
#  1   Age                      270 non-null    int64
#  2   Sex                      270 non-null    int64
#  3   Chest pain type          270 non-null    int64
#  4   BP                       270 non-null    int64
#  5   Cholesterol              270 non-null    int64
#  6   FBS over 120             270 non-null    int64
#  7   EKG results              270 non-null    int64
#  8   Max HR                   270 non-null    int64
#  9   Exercise angina          270 non-null    int64
#  10  ST depression            270 non-null    float64
#  11  Slope of ST              270 non-null    int64
#  12  Number of vessels fluro  270 non-null    int64
#  13  Thallium                 270 non-null    int64
# ...

# %%
df.describe()
# Out:
#             index         Age         Sex  Chest pain type          BP  \
# count  270.000000  270.000000  270.000000       270.000000  270.000000
# mean   134.500000   54.433333    0.677778         3.174074  131.344444
# std     78.086491    9.109067    0.468195         0.950090   17.861608
# min      0.000000   29.000000    0.000000         1.000000   94.000000
# 25%     67.250000   48.000000    0.000000         3.000000  120.000000
# 50%    134.500000   55.000000    1.000000         3.000000  130.000000
# 75%    201.750000   61.000000    1.000000         4.000000  140.000000
# max    269.000000   77.000000    1.000000         4.000000  200.000000
#
#        Cholesterol  FBS over 120  EKG results      Max HR  Exercise angina  \
# count   270.000000    270.000000   270.000000  270.000000       270.000000
# mean    249.659259      0.148148     1.022222  149.677778         0.329630
# std      51.686237      0.355906     0.997891   23.165717         0.470952
# ...

# %%
df.shape[0]
# Out:
# 270

# %%
df.tail()
# Out:
#      index  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 265    265   52    1                3  172          199             1
# 266    266   44    1                2  120          263             0
# 267    267   56    0                2  140          294             0
# 268    268   57    1                4  140          192             0
# 269    269   67    1                4  160          286             0
#
#      EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 265            0     162                0            0.5            1
# 266            0     173                0            0.0            1
# 267            2     153                0            1.3            2
# 268            0     148                0            0.4            2
# 269            2     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 265                        0         7       Absence
# ...

# %%
df.shape[1]
# Out:
# 15

# %%
df["Heart Disease"][1:5]
# Out:
# 1     Absence
# 2    Presence
# 3     Absence
# 4     Absence
# Name: Heart Disease, dtype: object

# %%
df.isnull()
# Out:
#      index    Age    Sex  Chest pain type     BP  Cholesterol  FBS over 120  \
# 0    False  False  False            False  False        False         False
# 1    False  False  False            False  False        False         False
# 2    False  False  False            False  False        False         False
# 3    False  False  False            False  False        False         False
# 4    False  False  False            False  False        False         False
# ..     ...    ...    ...              ...    ...          ...           ...
# 265  False  False  False            False  False        False         False
# 266  False  False  False            False  False        False         False
# 267  False  False  False            False  False        False         False
# 268  False  False  False            False  False        False         False
# 269  False  False  False            False  False        False         False
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# index                      0
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.duplicated().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# Length: 270, dtype: bool>

# %%
df=df.drop_duplicates()

# %%
df.shape[0]
# Out:
# 270

# %%
df.shape
# Out:
# (270, 15)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#             index         Age         Sex  Chest pain type          BP  \
# count  270.000000  270.000000  270.000000       270.000000  270.000000
# mean   134.500000   54.433333    0.677778         3.174074  131.344444
# std     78.086491    9.109067    0.468195         0.950090   17.861608
# min      0.000000   29.000000    0.000000         1.000000   94.000000
# 25%     67.250000   48.000000    0.000000         3.000000  120.000000
# 50%    134.500000   55.000000    1.000000         3.000000  130.000000
# 75%    201.750000   61.000000    1.000000         4.000000  140.000000
# max    269.000000   77.000000    1.000000         4.000000  200.000000
#
#        Cholesterol  FBS over 120  EKG results      Max HR  Exercise angina  \
# count   270.000000    270.000000   270.000000  270.000000       270.000000
# mean    249.659259      0.148148     1.022222  149.677778         0.329630
# std      51.686237      0.355906     0.997891   23.165717         0.470952
# ...

# %%
df["Heart Disease"]
# Out:
# 0      Presence
# 1       Absence
# 2      Presence
# 3       Absence
# 4       Absence
#          ...
# 265     Absence
# 266     Absence
# 267     Absence
# 268     Absence
# 269    Presence
# Name: Heart Disease, Length: 270, dtype: object

# %%
df.loc[df["Heart Disease"]=="Presence"].shape[0]
# Out:
# 120

# %%
df["FBS over 120"].value_counts()
# Out:
# 0    230
# 1     40
# Name: FBS over 120, dtype: int64

# %%
sns.countplot(df["Heart Disease"])
# Out:
# C:\Users\JS-MED\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
dfdis=df.loc[df["Heart Disease"]=="Presence"]
df.shape
# Out:
# (270, 15)

# %%
dfdis.shape
# Out:
# (120, 15)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dfdis.corr(),annot=True,cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
df["Sex"]
# Out:
# 30    1
# 31    1
# 32    0
# 33    1
# 34    1
# 35    1
# 36    1
# 37    1
# 38    1
# 39    1
# 40    1
# 41    0
# 42    1
# 43    1
# 44    1
# 45    1
# 46    1
# 47    1
# 48    1
# 49    0
# 50    1
# 51    1
# 52    0
# 53    0
# 54    0
# 55    0
# 56    1
# 57    0
# 58    0
# 59    1
# Name: Sex, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# 1    183
# 0     87
# Name: Sex, dtype: int64

# %%
male=df.loc[df["Sex"]==1].shape[0]
male
# Out:
# 183

# %%
female=df.loc[df["Sex"]==0].shape[0]
female
# Out:
# 87

# %%
sns.countplot(df["Sex"])
plt.xticks([0,1],['Female','Male'])
# Out:
# C:\Users\JS-MED\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ([<matplotlib.axis.XTick at 0x16542a332e0>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
sns.countplot(dfdis["Sex"])
plt.xticks([0,1],['Female','Male'])
# Out:
# C:\Users\JS-MED\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ([<matplotlib.axis.XTick at 0x1654465d160>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Sex',hue='Heart Disease',data=df)
plt.xticks([0,1],["Female","Male"])
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.distplot(x=df['Age'],bins=20)
# Out:
# C:\Users\JS-MED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df.columns
# Out:
# Index(['index', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol',
#        'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina',
#        'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium',
#        'Heart Disease'],
#       dtype='object')

# %%
sns.displot(x=df["Sex"],hue=df["Sex"])
plt.xticks([0,1],["Female","Male"])
# Out:
# ([<matplotlib.axis.XTick at 0x1654f726670>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
df['Chest pain type'].value_counts()
# Out:
# 4    129
# 3     79
# 2     42
# 1     20
# Name: Chest pain type, dtype: int64

# %%
sns.countplot(x='Chest pain type',hue='Heart Disease',data=df)
# Out:
# <AxesSubplot:xlabel='Chest pain type', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(x=df["BP"],bins=30)

plt.xticks(np.arange(min(df['BP']),max(df['BP'])+1,6),)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(x=df["Sex"], y=df["BP"])

# %%
df["BP"].max()
# Out:
# 200

# %%
only=df.loc[(df["Sex"]==1.0)|(df["Sex"])==0.0].shape[0]

# %%
plt.bar(df['Sex'],df['BP'])
# Out:
# <BarContainer object of 270 artists>

# %%
g=sns.FacetGrid(df,hue="Sex",aspect=4)
g.map(sns.kdeplot,'BP',shade=True)
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol',
#        'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina',
#        'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium',
#        'Heart Disease'],
#       dtype='object')

# %%
sns.displot(x=df["Sex"],y=df["BP"],hue=df['Sex'])

# %%
df.columns
# Out:
# Index(['index', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol',
#        'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina',
#        'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium',
#        'Heart Disease'],
#       dtype='object')

# %%
df["Cholesterol"].value_counts()
# Out:
# 234    6
# 254    5
# 269    5
# 226    4
# 204    4
#       ..
# 220    1
# 217    1
# 216    1
# 215    1
# 417    1
# Name: Cholesterol, Length: 144, dtype: int64

# %%
df["Cholesterol"].hist()
plt.xlabel("cholestrol value")
plt.ylabel("No of people")
# Out:
# Text(0, 0.5, 'No of people')

# %%
import pandas as pd

df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'value': [1, 2, 3, 4, 5, 6]})

grouped = df.groupby('key')['value'].sum()
grouped
# Out:
# key
# A    5
# B    7
# C    9
# Name: value, dtype: int64

# %%
df
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   A      4
# 4   B      5
# 5   C      6
